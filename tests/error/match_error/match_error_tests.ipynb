# %% [markdown]
# ### Errors

# %%
from guppylang import guppy

@guppy.enum
class Point:
    North = {"A": int}
    South = {"B": int}
    East = {}
    West = {}

@guppy
def g() -> Point:
    return Point.North(5)

@guppy
def main(north: Point, x: int) -> None:
    match north:
        case g():  # ERROR: match on a function
            x = 99

main.check()
# Out:
# Error: Expected a struct class (at <In[1]>:17:13)
#    |
# 15 | def main(north: Enum, x: int) -> None:
# 16 |     match north:
# 17 |         case g():  # ERROR: match on a function
#    |              ^ Expected a struct class, got a function call
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy

@guppy.enum
class Point:
    North = {"A": int}
    South = {"B": int}
    East = {}
    West = {}

    @guppy
    def str_(self) -> str:
        return "Direction"


@guppy
def main(north: Point, x: int) -> None:
    match p:
        case Point.North(): # ERROR: match on a struct method
            x = 77

main.check()
# Out:
# Error: Variable not defined (at <In[2]>:17:10)
#    |
# 15 | @guppy
# 16 | def main(north: Enum, x: int) -> None:
# 17 |     match p:
#    |           ^ `p` is not defined
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy

@guppy.enum
class Point:
    North = {"A": int}
    South = {"B": int}
    East = {}
    West = {}

    @guppy
    def str_(self) -> str:
        return "Direction"


@guppy
def main(north: Point, x: int) -> None:
    match north:
        case p():
            x = 77

main.check()
# Out:
# Error: Class not defined (at <In[3]>:18:13)
#    |
# 16 | def main(north: Enum, x: int) -> None:
# 17 |     match north:
# 18 |         case p():
#    |              ^ `p` is not defined
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy

@guppy.enum
class Point:
    North = {"A": int}
    South = {"B": int}
    East = {}
    West = {}

    @guppy
    def method(self) -> str:
        return "Direction"


@guppy
def main(north: Point, x: int) -> None:
    match north:
        case north.method():
            x = 77

main.check()
# Out:
# Error: Expected a enum class (at <In[4]>:18:13)
#    |
# 16 | def main(north: Enum, x: int) -> None:
# 17 |     match north:
# 18 |         case north.method():
#    |              ^^^^^ Expected a enum class, got a local variable
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy

@guppy.enum
class Point:
    f = {"m": int}
    Var = {}


@guppy
def main(i: Point) -> str:
    match i:
        case Point.f.m(): 
            return "One" 
    return "Not One"

main.check()
# Out:
# Error: Expected a struct or enum class (at <In[6]>:12:13)
#    |
# 10 | def main(i: Enum) -> str:
# 11 |     match i:
# 12 |         case Enum.f.m():
#    |              ^^^^^^^^^^ Expected a struct or enum class, got a function call
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy


@guppy.struct
class Point:
    x: int
    y: int

@guppy
def main(p: Point, x: int) -> None:
    match p:
        case Point():
            z = 66

main.check()
# Out:
# Error: Not enough arguments (at <In[7]>:12:13)
#    |
# 10 | def main(p: Point, x: int) -> None:
# 11 |     match p:
# 12 |         case Point():
#    |              ^^^^^^^ Expected 2, got 0
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy


@guppy.struct
class Point:
    x: int
    y: int

@guppy
def main(p: Point, x: int) -> None:
    match p:
        case Point(_):
            z = 66

main.check()
# Out:
# Error: Not enough arguments (at <In[8]>:12:13)
#    |
# 10 | def main(p: Point, x: int) -> None:
# 11 |     match p:
# 12 |         case Point(_):
#    |              ^^^^^^^^ Expected 2, got 1
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy


@guppy.struct
class Point:
    x: int
    y: int

@guppy
def main(p: Point, x: int) -> None:
    match p:
        case Point("_","2"):
            z = 66

main.check()
# Out:
# Error: Type mismatch (at <In[9]>:12:19)
#    |
# 10 | def main(p: Point, x: int) -> None:
# 11 |     match p:
# 12 |         case Point("_","2"):
#    |                    ^^^ Expected pattern of type `int`, got `str`
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy

@guppy.enum
class Point:
    North = {"A": int}


@guppy.struct
class Point:
    x: int

@guppy
def main(north: Point, x: int) -> None:
    match north:
        case Point(1):
            x = 44

main.check()
# Out:
# Error: Type mismatch (at <In[10]>:15:13)
#    |
# 13 | def main(north: Enum, x: int) -> None:
# 14 |     match north:
# 15 |         case Point(1):
#    |              ^^^^^ Expected pattern of type `Enum`, got `Point`
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy

@guppy.struct
class Point:
    x: int
    y: int

@guppy
def main(p: Point) -> None:
    match p:
        case Point(x, y):
            z = 44

main.check()
# Out:
# Error: Unsupported (at <In[11]>:11:19)
#    |
#  9 | def main(p: Point) -> None:
# 10 |     match p:
# 11 |         case Point(x, y):
#    |                    ^ Aliasing in patterns is not supported
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy

@guppy.struct
class Point:
    x: int
    y: int

@guppy
def main(p: Point) -> None:
    match p:
        case Point(_, _) as x:
            z = 44

main.check()
# Out:
# Error: Unsupported (at <In[12]>:11:13)
#    |
#  9 | def main(p: Point) -> None:
# 10 |     match p:
# 11 |         case Point(_, _) as x:
#    |              ^^^^^^^^^^^^^^^^ Aliasing in patterns is not supported
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy
from guppylang.std.quantum import qubit

import guppylang

guppylang.enable_experimental_features()

@guppy.enum
class Point:
    North = {"q": int}



@guppy
def f(e: Point) -> None:
    match e:
        case Point.North:
            pass

f.check()
# Out:
# Error: Expected literal (at <In[13]>:17:13)
#    |
# 15 | def f(e: Enum) -> None:
# 16 |     match e:
# 17 |         case Enum.North:
#    |              ^^^^^^^^^^ Expected literal
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy

@guppy.enum
class Point:
    North = {"A": int}
    South = {"B": int}
    East = {}
    West = {}

@guppy
def main(x: int, a: int) -> None:
    match x:
        case _ if a > 0:
            pass


main.check()
# Out:
# Error: Unsupported (at <In[14]>:13:18)
#    |
# 11 | def main(x: int, a: int) -> None:
# 12 |     match x:
# 13 |         case _ if a > 0:
#    |                   ^^^^^ Guarded patterns is not supported
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy

@guppy.enum
class Point:
    North = {}
    South = {}
    East = {}
    West = {}

@guppy
def main(x: int, a: int) -> None:
    match x:
        case Point.North() | Point.South():
            pass

main.check()
# Out:
# Error: Unsupported (at <In[15]>:13:13)
#    |
# 11 | def main(x: int, a: int) -> None:
# 12 |     match x:
# 13 |         case Enum.North() | Enum.South():
#    |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^ This pattern is not supported
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy
from typing import Generic

T = guppy.type_var("T")

@guppy.enum
class Point(Generic[T]):      # pyright: ignore[reportInvalidTypeForm]
    North = {"A": T}

@guppy.struct
class Point(Generic[T]):          # pyright: ignore[reportInvalidTypeForm] # type: ignore
    x: T
    y: int                          # pyright: ignore[reportInvalidTypeForm] # type: ignore

@guppy
def main() -> None:
    match Point(Point.North(3), 5):
        case Point(Point.North("7"), _):
            pass


main.check()
# Out:
# Error: Type mismatch (at <In[16]>:18:30)
#    |
# 16 | def main() -> None:
# 17 |     match Point(Enum.North(3), 5):
# 18 |         case Point(Enum.North("7"), _):
#    |                               ^^^ Expected pattern of type `int`, got `str`
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy
from typing import Generic

T = guppy.type_var("T")

@guppy.enum
class Point(Generic[T]):        # pyright: ignore[reportInvalidTypeForm]
    North = {"A": T}

@guppy.enum
class EnumGen(Generic[T]):          # pyright: ignore[reportInvalidTypeForm]
    Var = {"A": T}

@guppy.struct
class Point(Generic[T]):            # pyright: ignore[reportInvalidTypeForm]
    x: T                            # pyright: ignore[reportInvalidTypeForm]
    y: int                          # pyright: ignore[reportInvalidTypeForm]

@guppy
def main() -> None:
    match Point(Point.North(3), 5):
        case Point(EnumGen.Var(7), _):
            pass


main.check()
# Out:
# Error: Type mismatch (at <In[17]>:22:19)
#    |
# 20 | def main() -> None:
# 21 |     match Point(Enum.North(3), 5):
# 22 |         case Point(EnumGen.Var(7), _):
#    |                    ^^^^^^^ Expected pattern of type `Enum[int]`, got `EnumGen[T]`
#
# Guppy compilation failed due to 1 previous error

# %%
from typing import Generic

from guppylang import guppy
import guppylang

guppylang.enable_experimental_features()

T = guppy.type_var("T")

@guppy.struct
class Point(Generic[T]):              # pyright: ignore[reportInvalidTypeForm]
    A: T                                  # pyright: ignore[reportInvalidTypeForm]

@guppy
def main(d: Point[T]) -> None:         # pyright: ignore[reportInvalidTypeForm]
    match d:
        case Point(1):
            pass
    


main.compile().modules[0].render_dot()
# Out:
# Error: Type mismatch (at <In[18]>:17:18)
#    |
# 15 | def main(d: Enum[T]) -> None:         # pyright: ignore[reportInvalidTypeForm]
# 16 |     match d:
# 17 |         case Enum(1):
#    |                   ^ Expected pattern of type `T`, got `int`
#
# Guppy compilation failed due to 1 previous error

# %%
from typing import Generic

from guppylang import guppy
import guppylang

guppylang.enable_experimental_features()

T = guppy.type_var("T")
x = "1"
@guppy.enum
class Point(Generic[T]):              # pyright: ignore[reportInvalidTypeForm]
    Var = {"value": T}                      # pyright: ignore[reportInvalidTypeForm]

@guppy
def main(d: Point[T]) -> None:         # pyright: ignore[reportInvalidTypeForm]
    match d:
        case Point.Var(1):
            pass

main.compile().modules[0].render_dot()
# Out:
# Error: Type mismatch (at <In[19]>:17:22)
#    |
# 15 | def main(d: Enum[T]) -> None:         # pyright: ignore[reportInvalidTypeForm]
# 16 |     match d:
# 17 |         case Enum.Var(1):
#    |                       ^ Expected pattern of type `T`, got `int`
#
# Guppy compilation failed due to 1 previous error

# %%
@guppy.struct
class MyStruct:
    x: int

@guppy
def foo(s: MyStruct) -> None:
    MyStruct = 42
    match s:
        case MyStruct():
            pass

foo.check()
# Out:
# Error: Expected a struct class (at <In[20]>:9:13)
#   |
# 7 |     MyStruct = 42
# 8 |     match s:
# 9 |         case MyStruct():
#   |              ^^^^^^^^ Expected a struct class, got a local variable
#
# Guppy compilation failed due to 1 previous error

# %% [markdown]
# ### Python errors

# %%
from guppylang import guppy

@guppy.enum
class Point:
    North = {"A": int}
    South = {"B": int}
    East = {}
    West = {}

@guppy
def main(north: Point, x: int) -> None:
    match north:
        case x: # ERROR: match-as not supported
            x = 66
        case _:
            x = 55

main.check()

# %%
from guppylang import guppy

@guppy
def main(i: int):
    match i:
        case _: # Error: python do not allow this, good!
            return "One"     
        case 2: 
            return f"Two"

main.check()

# %%
from guppylang import guppy

@guppy
def main(i: int):
    match i:
        case 1 | x:
            return "1 or x"   
main.check()
