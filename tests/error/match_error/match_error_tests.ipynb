# %%
from guppylang import guppy

@guppy.enum
class Direction:
    North = {"A": int}
    South = {"B": int}
    East = {}
    West = {}

    @guppy
    def str_(self) -> str:
        return "Direction"

@guppy.struct
class Point:
    x: int
    y: int

    @guppy
    def method(self) -> int:
        return self.x + self.y

@guppy
def g() -> Direction:
    return Direction.North(5)

# %%
from guppylang import guppy

@guppy.enum
class Direction:
    North = {"A": int}
    South = {"B": int}
    East = {}
    West = {}

@guppy
def g() -> Direction:
    return Direction.North(5)

@guppy
def main(north: Direction, x: int) -> None:
    match north:
        case g():  # ERROR: match on a function
            x = 99

main.check()
# Out:
# dict_items([('cls', Name(id='g', ctx=Load())), ('patterns', []), ('kwd_attrs', []), ('kwd_patterns', []), ('lineno', 4), ('col_offset', 13), ('end_lineno', 4), ('end_col_offset', 16), ('line_offset', 14), ('file', '/var/folders/sx/bbzfd6mn5txdvh5bghnjgp5m0000gp/T/ipykernel_97369/2988572417.py'), ('source', '@guppy\ndef main(north: Direction, x: int) -> None:\n    match north:\n        case g():  # ERROR: match on a function\n            x = 99\n')])
# Error: Expected a value or a class (at <In[5]>:17:13)
#    |
# 15 | def main(north: Direction, x: int) -> None:
# 16 |     match north:
# 17 |         case g():  # ERROR: match on a function
#    |              ^ Expected a value or a class, got a function call
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy

@guppy.enum
class Direction:
    North = {"A": int}
    South = {"B": int}
    East = {}
    West = {}

    @guppy
    def str_(self) -> str:
        return "Direction"

@guppy.struct
class Point:
    x: int
    y: int

    @guppy
    def method(self) -> int:
        return self.x + self.y

@guppy
def main(north: Direction, x: int) -> None:
    match north:
        case Direction.str_(): # ERROR: match on a method enum
            x = 88
        case p.method(): # ERROR: match on a struct method
            x = 77

main.check()
# Out:
# Error: Expected a value or a class (at <In[1]>:26:13)
#    |
# 24 | def main(north: Direction, x: int) -> None:
# 25 |     match north:
# 26 |         case Direction.str_(): # ERROR: match on a method enum
#    |              ^^^^^^^^^^^^^^ Expected a value or a class, got a function call
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy

@guppy.enum
class Direction:
    North = {"A": int}
    South = {"B": int}
    East = {}
    West = {}

@guppy
def main(north: Direction, x: int) -> None:
    match north:
        case x: # ERROR: match-as not supported
            x = 66
        case Class() as var: # ERROR: match-as not supported
            x = 55

main.check()
# Out:
#   Cell In[4], line 4
#     case x: # ERROR: match-as not supported
#          ^
# SyntaxError: name capture 'x' makes remaining patterns unreachable

# %%
from guppylang import guppy

@guppy.enum
class Direction:
    North = {"A": int}
    South = {"B": int}
    East = {}
    West = {}

@guppy.struct
class Point:
    x: int
    y: int

@guppy
def main(north: Direction, x: int) -> None:
    match north:
        case Point(1): # ERROR: wrong type/wrong number of args
            x = 44

main.check()
# Out:
# Error: Type mismatch (at <In[6]>:4:13)
#   |
# 2 | def main(north: Direction, x: int) -> None:
# 3 |     match north:
# 4 |         case Point(1): # ERROR: wrong type/wrong number of args
#   |              ^^^^^^^^ Expected pattern of type `Direction`, got `Point`
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy

@guppy.enum
class Direction:
    North = {"A": int}
    South = {"B": int}
    East = {}
    West = {}

@guppy.struct
class Point:
    x: int
    y: int

@guppy
def main(north: Direction, x: int) -> None:
    match north:
        case Point(): # ERROR: different type
            z = 66

main.check()
# Out:
# Error: Type mismatch (at <In[8]>:4:13)
#   |
# 2 | def main(north: Direction, x: int) -> None:
# 3 |     match north:
# 4 |         case Point(): # ERROR: different type
#   |              ^^^^^^^ Expected pattern of type `Direction`, got `Point`
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy

@guppy
def main(i: int):
    match i:
        case _: # Error: python do not allow this, good!
            return "One"
        case 1 | x: # Same here, python do not allow this, good!
            return "1 or x"        
        case 2: 
            return f"Two"

main.check()
# Out:
#   Cell In[9], line 4
#     case _: # Error: python do not allow this, good!
#          ^
# SyntaxError: wildcard makes remaining patterns unreachable

# %%
from guppylang import guppy

@guppy.struct
class Point:
    x: int
    y: int

@guppy
def main(p: Point) -> None:
    match p:
        case Point(x, y):
            z = 44

main.check()
# Out:
# Error: Unsupported (at <In[10]>:11:19)
#    |
#  9 | def main(p: Point) -> None:
# 10 |     match p:
# 11 |         case Point(x, y):
#    |                    ^ This pattern is not supported
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy

@guppy.enum
class Enum:
    f = {"m": int}
    Var = {}


@guppy
def main(i: Enum) -> str:
    match i:
        case Enum.f.m(): 
            return "One" 
    return "Not One"

main.check()
# Out:
# Error: Expected a value or a class (TODO ERROR) (at <In[2]>:12:13)
#    |
# 10 | def main(i: Enum) -> str:
# 11 |     match i:
# 12 |         case Enum.f.m():
#    |              ^^^^^^^^^^ Expected a value or a class (TODO ERROR)
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang import guppy
from guppylang.std.quantum import qubit

import guppylang

guppylang.enable_experimental_features()

@guppy.enum
class Direction:
    North = {"q": int}
    South = {"q": int}
    East = {"q": int}
    West = {"q": int}


@guppy
def f(e: Direction) -> int:
    match e:
        case Direction.North:
            return 42
        case _:
            return 0

    return 0

f.check()
# Out:
# Attribute(value=Name(id='Direction', ctx=Load()), attr='North', ctx=Load())
# Error: Unsupported (at <In[5]>:19:13)
#    |
# 17 | def f(e: Direction) -> int:
# 18 |     match e:
# 19 |         case Direction.North:
#    |              ^^^^^^^^^^^^^^^ TODO ERROR is not supported
#
# Guppy compilation failed due to 1 previous error

# %%
from guppylang.std.quantum import qubit

@guppy.struct
class Point:
    x: int
    y: int

@guppy
def main(p: Point) -> None:
    match p:
        case Point(3, 4):
            q = qubit()  # ERROR if qubit is linear and cannot be reused
            a = q, q
        case Point(5, 6):
            b = p.x  # ERROR if p.x is linear and cannot be reused

main.check()
# Out:
# 2
# 2
# Error: Copy violation (at <In[4]>:13:19)
#    |
# 11 |         case Point(3, 4):
# 12 |             q = qubit()  # ERROR if qubit is linear and cannot be reused
# 13 |             a = q, q
#    |                    ^ Variable `q` with non-copyable type `qubit` cannot be moved
#    |                      ...
#
# Note:
#    |
# 12 |             q = qubit()  # ERROR if qubit is linear and cannot be reused
# 13 |             a = q, q
#    |                 - Variable `q` already moved here
#
# Guppy compilation failed due to 1 previous error

# %%
# Example: linear variable used in multiple match arms (should error if not allowed)
from guppylang import guppy
from guppylang.std.quantum import qubit, measure

@guppy.struct
class Point:
    x: int
    y: int


@guppy
def main(p: Point) -> None:
    q = qubit()  # ERROR if qubit is linear and cannot be reused
    match p:
        case Point(3, 4):
            measure(q)  # ERROR if qubit is linear and cannot be reused
        case Point(5, 6):
            b = p.x  # ERROR if p.x is linear and cannot be reused

main.check()
# Out:
# Error: Expected a struct class (at <In[1]>:15:13)
#    |
# 13 |     q = qubit()  # ERROR if qubit is linear and cannot be reused
# 14 |     match p:
# 15 |         case Point(3, 4):
#    |              ^^^^^ Expected a struct class, got TODO ERROR4
#
# Guppy compilation failed due to 1 previous error

# %%
# Unreachable pattern after catch-all
from guppylang import guppy

@guppy
def main(i: int):
    match i:
        case x:
            return x
        case 3: # ERROR: unreachable pattern
            return 3

main.check()
# Out:
#   Cell In[14], line 5
#     case x:
#          ^
# SyntaxError: name capture 'x' makes remaining patterns unreachable

# %%
# Guard and or-patterns (should error if not supported)
from guppylang import guppy

@guppy.enum
class Direction:
    North = {"A": int}
    South = {"B": int}
    East = {}
    West = {}

@guppy
def main(x: int, a: int) -> None:
    match x:
        case _ if a > 0: # Is this fine? (should error if guards not supported)
            pass
        case Direction.North | Direction.South: # No FOR NOW (should error)
            pass

main.check()
# Out:
# Error: Unsupported (at <In[16]>:7:13)
#   |
# 5 |         case _ if a > 0: # Is this fine? (should error if guards not supported)
# 6 |             pass
# 7 |         case Direction.North | Direction.South: # No FOR NOW (should error)
#   |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ This pattern is not supported
#
# Guppy compilation failed due to 1 previous error

# %%
# Minimal valid match statement (should compile)
from guppylang import guppy

@guppy.enum
class Direction:
    North = {"A": int}
    South = {"B": int}
    East = {}
    West = {}

@guppy
def main(north: Direction) -> int:
    match north:
        case Direction.North(1):
            return 1
        case Direction.South:
            return 2
        case _:
            return 0

main.check()
# Out:
# MatchValue(value=Constant(value=1, kind=None)) FuncInput(ty=NumericType(kind=<Kind.Int: 2>), flags=<InputFlags.NoFlags: 0>, name='A')
# Pattern subst: {}
# Pattern subst: {}
